# %%
from google.colab import drive
drive.mount('/content/drive')

# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth vllm
# Install latest Hugging Face for Gemma-3!
# !pip install --no-deps git+https://github.com/huggingface/transformers@v4.49.0-Gemma-3
# Out:
# Mounted at /content/drive
# Collecting unsloth
#   Downloading unsloth-2025.3.19-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 2.3 MB/s eta 0:00:00
# Collecting vllm
#   Downloading vllm-0.8.2-cp38-abi3-manylinux1_x86_64.whl.metadata (27 kB)
# Downloading unsloth-2025.3.19-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.7/192.7 kB 8.1 MB/s eta 0:00:00
# Downloading vllm-0.8.2-cp38-abi3-manylinux1_x86_64.whl (293.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: vllm, unsloth
# Successfully installed unsloth-2025.3.19 vllm-0.8.2
# Collecting git+https://github.com/huggingface/transformers@v4.49.0-Gemma-3
#   Cloning https://github.com/huggingface/transformers (to revision v4.49.0-Gemma-3) to /tmp/pip-req-build-ktjge1b8
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-ktjge1b8
#   Running command git checkout -q 367bab469b0ef32017e2a0a0a5dbac5d36002f03
#   Resolved https://github.com/huggingface/transformers to commit 367bab469b0ef32017e2a0a0a5dbac5d36002f03
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.50.0.dev0-py3-none-any.whl size=10936468 sha256=c3fedd4c1cb04bf1948545bc3b4233b4fc7b3138f0bcf274cc2bcbaaa3afbba5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p5fxoc5y/wheels/53/15/d5/d63b866c641d8863f9cd29a4cc7a5efc38476c3aae8247c195
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.0
#     Uninstalling transformers-4.50.0:
#       Successfully uninstalled transformers-4.50.0
# Successfully installed transformers-4.50.0.dev0

# %%
# !pip install bitsandbytes
# !pip install unsloth_zoo
# !pip install msgspec
# !pip install blake3
# !pip install gguf
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.4-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.4-py3-none-manylinux_2_24_x86_64.whl (76.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 MB 30.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth 2025.3.19 requires datasets>=2.16.0, which is not installed.
# unsloth 2025.3.19 requires hf_transfer, which is not installed.
# unsloth 2025.3.19 requires trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9, which is not installed.
# unsloth 2025.3.19 requires tyro, which is not installed.
# unsloth 2025.3.19 requires unsloth_zoo>=2025.3.17, which is not installed.
# unsloth 2025.3.19 requires xformers>=0.0.27.post2, which is not installed.
# unsloth 2025.3.19 requires protobuf<4.0.0, but you have protobuf 5.29.4 which is incompatible.
# Successfully installed bitsandbytes-0.45.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting unsloth_zoo
#   Downloading unsloth_zoo-2025.3.17-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (2.6.0+cu124)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (3.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (24.2)
# Collecting tyro (from unsloth_zoo)
#   Downloading tyro-0.9.17-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: transformers!=4.47.0,>=4.46.1 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (4.50.0.dev0)
# Collecting datasets>=2.16.0 (from unsloth_zoo)
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (2.0.2)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (1.5.2)
# Collecting trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9 (from unsloth_zoo)
#   Downloading trl-0.15.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (0.14.0)
# Collecting protobuf<4.0.0 (from unsloth_zoo)
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (0.29.3)
# Collecting hf_transfer (from unsloth_zoo)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting cut_cross_entropy (from unsloth_zoo)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (11.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (2024.11.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.1->unsloth_zoo) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.1->unsloth_zoo) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth_zoo) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth_zoo) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.16.0->unsloth_zoo)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth_zoo) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth_zoo) (2.32.3)
# Collecting xxhash (from datasets>=2.16.0->unsloth_zoo)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.16.0->unsloth_zoo)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.16.0->unsloth_zoo)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth_zoo) (3.11.14)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->unsloth_zoo) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->unsloth_zoo) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->unsloth_zoo) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,>=4.46.1->unsloth_zoo) (0.21.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth_zoo) (13.9.4)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth_zoo) (0.16)
# Collecting shtab>=1.5.6 (from tyro->unsloth_zoo)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth_zoo) (4.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth_zoo) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth_zoo) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth_zoo) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth_zoo) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth_zoo) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth_zoo) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth_zoo) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth_zoo) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth_zoo) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth_zoo) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth_zoo) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth_zoo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth_zoo) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->unsloth_zoo) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth_zoo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth_zoo) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth_zoo) (2025.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth_zoo) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth_zoo) (1.17.0)
# Downloading unsloth_zoo-2025.3.17-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 5.5 MB/s eta 0:00:00
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 15.2 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 16.6 MB/s eta 0:00:00
# Downloading trl-0.15.2-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 28.0 MB/s eta 0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 78.7 MB/s eta 0:00:00
# Downloading tyro-0.9.17-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 10.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.9 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 20.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.3 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, shtab, protobuf, hf_transfer, fsspec, dill, multiprocess, tyro, datasets, cut_cross_entropy, trl, unsloth_zoo
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.8.2 requires blake3, which is not installed.
# vllm 0.8.2 requires compressed-tensors==0.9.2, which is not installed.
# vllm 0.8.2 requires depyf==0.18.0, which is not installed.
# vllm 0.8.2 requires fastapi[standard]>=0.115.0, which is not installed.
# vllm 0.8.2 requires gguf==0.10.0, which is not installed.
# vllm 0.8.2 requires lark==1.2.2, which is not installed.
# vllm 0.8.2 requires llguidance<0.8.0,>=0.7.9; platform_machine == "x86_64" or platform_machine == "arm64" or platform_machine == "aarch64", which is not installed.
# vllm 0.8.2 requires lm-format-enforcer<0.11,>=0.10.11, which is not installed.
# vllm 0.8.2 requires mistral_common[opencv]>=1.5.4, which is not installed.
# vllm 0.8.2 requires msgspec, which is not installed.
# vllm 0.8.2 requires ninja, which is not installed.
# vllm 0.8.2 requires outlines==0.1.11, which is not installed.
# vllm 0.8.2 requires partial-json-parser, which is not installed.
# vllm 0.8.2 requires prometheus-fastapi-instrumentator>=7.0.0, which is not installed.
# vllm 0.8.2 requires python-json-logger, which is not installed.
# vllm 0.8.2 requires ray[cgraph]>=2.43.0, which is not installed.
# vllm 0.8.2 requires tiktoken>=0.6.0, which is not installed.
# vllm 0.8.2 requires watchfiles, which is not installed.
# vllm 0.8.2 requires xformers==0.0.29.post2; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# vllm 0.8.2 requires xgrammar==0.1.16; platform_machine == "x86_64" or platform_machine == "aarch64", which is not installed.
# unsloth 2025.3.19 requires xformers>=0.0.27.post2, which is not installed.
# vllm 0.8.2 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<6.0.0dev,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# Successfully installed cut_cross_entropy-25.1.1 datasets-3.4.1 dill-0.3.8 fsspec-2024.12.0 hf_transfer-0.1.9 multiprocess-0.70.16 protobuf-3.20.3 shtab-1.7.1 trl-0.15.2 tyro-0.9.17 unsloth_zoo-2025.3.17 xxhash-3.5.0
# Collecting msgspec
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: msgspec
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.8.2 requires blake3, which is not installed.
# vllm 0.8.2 requires compressed-tensors==0.9.2, which is not installed.
# vllm 0.8.2 requires depyf==0.18.0, which is not installed.
# vllm 0.8.2 requires fastapi[standard]>=0.115.0, which is not installed.
# vllm 0.8.2 requires gguf==0.10.0, which is not installed.
# vllm 0.8.2 requires lark==1.2.2, which is not installed.
# vllm 0.8.2 requires llguidance<0.8.0,>=0.7.9; platform_machine == "x86_64" or platform_machine == "arm64" or platform_machine == "aarch64", which is not installed.
# vllm 0.8.2 requires lm-format-enforcer<0.11,>=0.10.11, which is not installed.
# vllm 0.8.2 requires mistral_common[opencv]>=1.5.4, which is not installed.
# vllm 0.8.2 requires ninja, which is not installed.
# vllm 0.8.2 requires outlines==0.1.11, which is not installed.
# vllm 0.8.2 requires partial-json-parser, which is not installed.
# vllm 0.8.2 requires prometheus-fastapi-instrumentator>=7.0.0, which is not installed.
# vllm 0.8.2 requires python-json-logger, which is not installed.
# vllm 0.8.2 requires ray[cgraph]>=2.43.0, which is not installed.
# vllm 0.8.2 requires tiktoken>=0.6.0, which is not installed.
# vllm 0.8.2 requires watchfiles, which is not installed.
# vllm 0.8.2 requires xformers==0.0.29.post2; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# vllm 0.8.2 requires xgrammar==0.1.16; platform_machine == "x86_64" or platform_machine == "aarch64", which is not installed.
# vllm 0.8.2 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# Successfully installed msgspec-0.19.0
# Collecting blake3
#   Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: blake3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.8.2 requires compressed-tensors==0.9.2, which is not installed.
# vllm 0.8.2 requires depyf==0.18.0, which is not installed.
# vllm 0.8.2 requires fastapi[standard]>=0.115.0, which is not installed.
# vllm 0.8.2 requires gguf==0.10.0, which is not installed.
# vllm 0.8.2 requires lark==1.2.2, which is not installed.
# vllm 0.8.2 requires llguidance<0.8.0,>=0.7.9; platform_machine == "x86_64" or platform_machine == "arm64" or platform_machine == "aarch64", which is not installed.
# vllm 0.8.2 requires lm-format-enforcer<0.11,>=0.10.11, which is not installed.
# vllm 0.8.2 requires mistral_common[opencv]>=1.5.4, which is not installed.
# vllm 0.8.2 requires ninja, which is not installed.
# vllm 0.8.2 requires outlines==0.1.11, which is not installed.
# vllm 0.8.2 requires partial-json-parser, which is not installed.
# vllm 0.8.2 requires prometheus-fastapi-instrumentator>=7.0.0, which is not installed.
# vllm 0.8.2 requires python-json-logger, which is not installed.
# vllm 0.8.2 requires ray[cgraph]>=2.43.0, which is not installed.
# vllm 0.8.2 requires tiktoken>=0.6.0, which is not installed.
# vllm 0.8.2 requires watchfiles, which is not installed.
# vllm 0.8.2 requires xformers==0.0.29.post2; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# vllm 0.8.2 requires xgrammar==0.1.16; platform_machine == "x86_64" or platform_machine == "aarch64", which is not installed.
# vllm 0.8.2 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# Successfully installed blake3-1.0.4
# Collecting gguf
#   Downloading gguf-0.14.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from gguf) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from gguf) (6.0.2)
# Requirement already satisfied: sentencepiece<=0.2.0,>=0.1.98 in /usr/local/lib/python3.11/dist-packages (from gguf) (0.2.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from gguf) (4.67.1)
# Downloading gguf-0.14.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: gguf
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.8.2 requires compressed-tensors==0.9.2, which is not installed.
# vllm 0.8.2 requires depyf==0.18.0, which is not installed.
# vllm 0.8.2 requires fastapi[standard]>=0.115.0, which is not installed.
# vllm 0.8.2 requires lark==1.2.2, which is not installed.
# vllm 0.8.2 requires llguidance<0.8.0,>=0.7.9; platform_machine == "x86_64" or platform_machine == "arm64" or platform_machine == "aarch64", which is not installed.
# vllm 0.8.2 requires lm-format-enforcer<0.11,>=0.10.11, which is not installed.
# vllm 0.8.2 requires mistral_common[opencv]>=1.5.4, which is not installed.
# vllm 0.8.2 requires ninja, which is not installed.
# vllm 0.8.2 requires outlines==0.1.11, which is not installed.
# vllm 0.8.2 requires partial-json-parser, which is not installed.
# vllm 0.8.2 requires prometheus-fastapi-instrumentator>=7.0.0, which is not installed.
# vllm 0.8.2 requires python-json-logger, which is not installed.
# vllm 0.8.2 requires ray[cgraph]>=2.43.0, which is not installed.
# vllm 0.8.2 requires tiktoken>=0.6.0, which is not installed.
# vllm 0.8.2 requires watchfiles, which is not installed.
# vllm 0.8.2 requires xformers==0.0.29.post2; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# vllm 0.8.2 requires xgrammar==0.1.16; platform_machine == "x86_64" or platform_machine == "aarch64", which is not installed.
# vllm 0.8.2 requires gguf==0.10.0, but you have gguf 0.14.0 which is incompatible.
# vllm 0.8.2 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# Successfully installed gguf-0.14.0

# %%
# 1. Import required libraries
import json
import torch
from unsloth import FastModel
from transformers import TextStreamer
from pathlib import Path
import time
import re

# 2. Define paths and settings
base_dir = "/content/drive/MyDrive/2025_ConvFinQA_SFT_Agentic"
model_path = f"{base_dir}/finqa-gemma3-program_answer-full"
data_dir = Path(f"{base_dir}/data/processed_datasets")
dev_path = data_dir / "finqa_program_answer_dev.jsonl"

# Toggle for verbose output - set to True to see all examples
VERBOSE_OUTPUT = True

# Maximum number of examples to evaluate (set to None to evaluate all)
# MAX_EXAMPLES: int | None = 100
MAX_EXAMPLES = 100

# 3. Load the fine-tuned model and tokenizer
print("Loading fine-tuned model...")
model, tokenizer = FastModel.from_pretrained(
    model_name = model_path,
    max_seq_length = 4096,
    load_in_4bit = True,
)

# 4. Set up the tokenizer with Gemma 3 chat template
from unsloth.chat_templates import get_chat_template
tokenizer = get_chat_template(
    tokenizer,
    chat_template = "gemma-3",
)
print("Model loaded successfully!")

# 5. Load all dev examples
print("Loading development examples...")
with open(dev_path, 'r') as f:
    dev_data = [json.loads(line) for line in f]
print(f"Loaded {len(dev_data)} dev examples")

# 6. Define a function to test the model on examples with recommended Gemma 3 parameters
def test_model_on_example(example, model, tokenizer):
    """Test the model on a single example using recommended Gemma 3 parameters"""
    # Create message format
    messages = [{
        "role": "user",
        "content": [{
            "type": "text",
            "text": example["prompt"].replace("### Response:\n", "")
        }]
    }]

    # Apply chat template
    text = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt = True,
    )

    # Generate response using recommended Gemma 3 parameters
    start_time = time.time()
    outputs = model.generate(
        **tokenizer([text], return_tensors="pt").to("cuda"),
        max_new_tokens = 1024,  # Increased for complex financial reasoning
        temperature = 1.0,      # Gemma 3 recommended
        top_p = 0.95,           # Gemma 3 recommended
        top_k = 64,             # Gemma 3 recommended
    )
    end_time = time.time()

    # Extract model output
    model_output = tokenizer.decode(outputs[0]).split("<start_of_turn>model\n")[1]
    if "<end_of_turn>" in model_output:
        model_output = model_output.split("<end_of_turn>")[0]

    generation_time = end_time - start_time

    return {
        "model_output": model_output,
        "expected_output": example.get("output", example.get("answer", "")),
        "generation_time": generation_time,
        "prompt": example["prompt"]  # Include prompt for reference
    }

# 7. Extract final answers for exact matching
def extract_final_answer(text):
    """Extract final answer from text, handling various formats"""
    if "Final Answer:" in text:
        final_answer = text.split("Final Answer:")[1].strip()
    elif "final answer:" in text.lower():
        final_answer = text.split("final answer:", 1)[1].strip()
    else:
        # If no explicit final answer marker, take the last sentence
        sentences = text.split('.')
        final_answer = sentences[-1].strip()

    # Clean up whitespace and punctuation for comparison
    final_answer = re.sub(r'\s+', ' ', final_answer).strip()
    final_answer = re.sub(r'[,.;:]$', '', final_answer).strip()

    return final_answer

# Updated numeric matching function with better rounding handling
def is_numeric_match(expected, generated):
    """Check if numbers in the answers match, including handling rounding differences"""
    # Extract all numbers from both strings
    expected_numbers = re.findall(r'-?[\d,]*\.\d+%?|-?\d+%?', expected)
    generated_numbers = re.findall(r'-?[\d,]*\.\d+%?|-?\d+%?', generated)

    # Check if we have numbers to compare
    if not expected_numbers or not generated_numbers:
        return False

    # Get the last number (final answer) from each
    expected_last = expected_numbers[-1]
    generated_last = generated_numbers[-1]

    # Check for percentage formatting
    expected_is_pct = expected_last.endswith('%')
    generated_is_pct = generated_last.endswith('%')

    # Convert to floats for comparison (remove % and ,)
    expected_float = float(expected_last.replace('%', '').replace(',', ''))
    generated_float = float(generated_last.replace('%', '').replace(',', ''))

    # Handle percentage rounding differences
    if expected_is_pct and generated_is_pct:
        # Allow more tolerance for percentages
        # For example, 62.9% and 63% should match
        return abs(expected_float - generated_float) <= 0.2  # Higher tolerance for percentages
    else:
        # For non-percentage values, use stricter comparison
        relative_diff = abs(expected_float - generated_float) / max(abs(expected_float), 0.0001)
        return relative_diff < 0.01  # 1% relative tolerance

# Helper function to extract question from prompt
def extract_question(prompt):
    """Extract the question part from a prompt"""
    if "### Question:" in prompt:
        question = prompt.split("### Question:")[1].split("### Response:")[0].strip()
    else:
        question = prompt.split("\n\n")[-2].strip()
    return question

# 8. Run full evaluation on the entire dev set
print("\n" + "="*80)
print("RUNNING FULL EVALUATION ON DEV SET")
print("="*80)

if VERBOSE_OUTPUT:
    print("Verbose output enabled - showing all examples")
else:
    print("Verbose output disabled - showing summary only")

# Track metrics
all_results = []
total_time = 0
exact_match_count = 0
numeric_match_count = 0

# Run evaluation
dev_data_to_evaluate = dev_data[:MAX_EXAMPLES] if MAX_EXAMPLES is not None else dev_data
total_examples = len(dev_data_to_evaluate)
print(f"Starting evaluation on {total_examples} examples...")

# Create output file for all predictions
predictions_file = f"{base_dir}/evaluation_outputs/all_predictions_program_full.jsonl"
with open(predictions_file, 'w') as pred_file:
    for i, example in enumerate(dev_data_to_evaluate):
        # Print progress updates
        if not VERBOSE_OUTPUT and ((i+1) % 25 == 0 or i+1 == total_examples):
            print(f"Progress: {i+1}/{total_examples} examples evaluated")

        # Run the model on this example
        result = test_model_on_example(example, model, tokenizer)

        # Extract final answers for comparison
        expected_answer = extract_final_answer(result["expected_output"])
        model_answer = extract_final_answer(result["model_output"])

        # Extract question for display
        question = extract_question(example["prompt"])

        # Check for exact match
        exact_match = expected_answer.lower() == model_answer.lower()
        if exact_match:
            exact_match_count += 1
            match_status = "exact"
        else:
            # Check for numeric match with improved tolerance
            numeric_match = is_numeric_match(expected_answer, model_answer)
            if numeric_match:
                numeric_match_count += 1
                match_status = "numeric"
            else:
                match_status = "incorrect"

        # Save results
        result["exact_match"] = exact_match
        result["numeric_match"] = numeric_match
        result["expected_final"] = expected_answer
        result["model_final"] = model_answer
        result["question"] = question
        result["match_status"] = match_status

        all_results.append(result)
        total_time += result["generation_time"]

        # Write individual result to JSONL file
        pred_file.write(json.dumps({
            "id": example.get("id", f"example_{i}"),
            "question": question,
            "expected_answer": expected_answer,
            "model_answer": model_answer,
            "exact_match": exact_match,
            "numeric_match": numeric_match,
            "match_status": match_status,
            "full_model_output": result["model_output"]
        }) + "\n")

        # Print verbose output if enabled
        if VERBOSE_OUTPUT:
            if exact_match:
                display_status = "[EXACT MATCH]"
            elif numeric_match:
                # Show the values for numeric matches to verify
                display_status = f"[NUMERIC MATCH: {expected_answer} ≈ {model_answer}]"
            else:
                display_status = "[INCORRECT]"

            print(f"\n{'-'*80}")
            print(f"Example {i+1}/{total_examples} {display_status}")
            print(f"Question: {question}")
            print(f"\nExpected answer: {expected_answer}")
            print(f"Model answer: {model_answer}")

            if not exact_match:  # Show full outputs for non-exact matches
                print("\nFull expected output:")
                print(result["expected_output"][:500] + "..." if len(result["expected_output"]) > 500 else result["expected_output"])
                print("\nFull model output:")
                print(result["model_output"][:500] + "..." if len(result["model_output"]) > 500 else result["model_output"])

            print(f"Generation time: {result['generation_time']:.2f} seconds")

print(f"\nAll predictions written to: {predictions_file}")

# 9. Calculate and print evaluation metrics
avg_generation_time = total_time / total_examples
exact_match_accuracy = (exact_match_count / total_examples) * 100
numeric_match_accuracy = ((exact_match_count + numeric_match_count) / total_examples) * 100

print("\n" + "="*80)
print("EVALUATION RESULTS")
print("="*80)
print(f"Total examples evaluated: {total_examples}")
print(f"Average generation time: {avg_generation_time:.2f} seconds")
print(f"Exact match accuracy: {exact_match_accuracy:.2f}%")
print(f"Numeric match accuracy (includes exact + approximate): {numeric_match_accuracy:.2f}%")
print(f"Exact matches: {exact_match_count}/{total_examples}")
print(f"Numeric-only matches: {numeric_match_count}/{total_examples}")

# 10. Analyze rounding differences
print("\n" + "="*80)
print("ROUNDING DIFFERENCE ANALYSIS")
print("="*80)

# Find examples where the only difference is rounding
rounding_differences = []
for result in all_results:
    if not result["exact_match"] and result["numeric_match"]:
        # Extract numbers from both answers
        expected_numbers = re.findall(r'-?[\d,]*\.\d+%?|-?\d+%?', result["expected_final"])
        generated_numbers = re.findall(r'-?[\d,]*\.\d+%?|-?\d+%?', result["model_final"])

        if expected_numbers and generated_numbers:
            expected_last = expected_numbers[-1]
            generated_last = generated_numbers[-1]

            # Only include if both have % or neither has %
            if expected_last.endswith('%') == generated_last.endswith('%'):
                expected_float = float(expected_last.replace('%', '').replace(',', ''))
                generated_float = float(generated_last.replace('%', '').replace(',', ''))

                difference = abs(expected_float - generated_float)
                if difference <= 0.2:  # Small rounding difference
                    rounding_differences.append({
                        "question": result["question"],
                        "expected": result["expected_final"],
                        "model": result["model_final"],
                        "difference": difference
                    })

# Print summary of rounding differences
print(f"Found {len(rounding_differences)} examples with rounding differences")
print(f"These are counted as correct in the numeric match accuracy")

# Show a few examples
if rounding_differences:
    print("\nExamples of rounding differences:")
    for i, rd in enumerate(rounding_differences[:5]):
        print(f"\nRounding Example {i+1}:")
        print(f"Question: {rd['question']}")
        print(f"Expected: {rd['expected']}")
        print(f"Model: {rd['model']}")
        print(f"Difference: {rd['difference']:.2f}")

# 11. Analyze errors to understand where the model struggles
print("\n" + "="*80)
print("ERROR ANALYSIS")
print("="*80)

# Categorize examples by steps required
examples_by_steps = {}
for example in dev_data:
    output = example.get("output", "")
    step_count = output.count("Step ")
    if step_count not in examples_by_steps:
        examples_by_steps[step_count] = []
    examples_by_steps[step_count].append(example)

# Calculate accuracy per step count
print("Accuracy by reasoning step count:")
for step_count in sorted(examples_by_steps.keys()):
    examples = examples_by_steps[step_count]
    correct = 0
    for ex in examples:
        for result in all_results:
            if result["expected_output"] == ex.get("output", "") and (result["exact_match"] or result["numeric_match"]):
                correct += 1
                break

    accuracy = (correct / len(examples)) * 100
    print(f"  {step_count} steps: {accuracy:.2f}% ({correct}/{len(examples)})")

# 12. Save detailed results to JSON for further analysis
results_file = f"{base_dir}/evaluation_outputs/evaluation_results_program_full.json"
with open(results_file, 'w') as f:
    # Create a summary object
    summary = {
        "total_examples": total_examples,
        "exact_match_accuracy": exact_match_accuracy,
        "numeric_match_accuracy": numeric_match_accuracy,
        "exact_match_count": exact_match_count,
        "numeric_match_count": numeric_match_count,
        "rounding_difference_count": len(rounding_differences),
        "avg_generation_time": avg_generation_time,
        "step_accuracies": {
            str(step_count): {
                "accuracy": (sum(1 for ex in examples_by_steps[step_count]
                             for res in all_results if res["expected_output"] == ex.get("output", "")
                             and (res["exact_match"] or res["numeric_match"])) / len(examples_by_steps[step_count])) * 100,
                "count": len(examples_by_steps[step_count])
            } for step_count in examples_by_steps
        }
    }

    # We need to clean the results for JSON serialization
    clean_results = []
    for res in all_results:
        clean_res = {
            "question": res["question"],
            "expected_final": res["expected_final"],
            "model_final": res["model_final"],
            "exact_match": res["exact_match"],
            "numeric_match": res["numeric_match"],
            "match_status": res["match_status"],
            "generation_time": res["generation_time"]
        }
        clean_results.append(clean_res)

    # Combine summary and results
    output_data = {
        "summary": summary,
        "rounding_differences": [{
            "question": rd["question"],
            "expected": rd["expected"],
            "model": rd["model"],
            "difference": rd["difference"]
        } for rd in rounding_differences],
        "results": clean_results
    }

    json.dump(output_data, f, indent=2)

print(f"\nDetailed results saved to {results_file}")

# 13. Display a few examples of correct and incorrect predictions if not in verbose mode
if not VERBOSE_OUTPUT:
    print("\n" + "="*80)
    print("EXAMPLE PREDICTIONS")
    print("="*80)

    # Get some correct and incorrect examples
    correct_examples = [res for res in all_results if res["exact_match"] or res["numeric_match"]]
    incorrect_examples = [res for res in all_results if not res["exact_match"] and not res["numeric_match"]]

    # Show 3 correct examples
    print("\nCORRECT PREDICTIONS:")
    for i, res in enumerate(correct_examples[:3]):
        print(f"\nCorrect Example {i+1}:")
        print(f"Question: {res['question']}")
        print(f"Expected: {res['expected_final']}")
        print(f"Model output: {res['model_final']}")
        print("-" * 50)

    # Show 3 incorrect examples
    print("\nINCORRECT PREDICTIONS:")
    for i, res in enumerate(incorrect_examples[:3]):
        print(f"\nIncorrect Example {i+1}:")
        print(f"Question: {res['question']}")
        print(f"Expected: {res['expected_final']}")
        print(f"Model output: {res['model_final']}")
        print("-" * 50)

print("\nEvaluation complete!")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-27 07:00:31 [__init__.py:239] Automatically detected platform cuda.
# Loading fine-tuned model...
# ==((====))==  Unsloth 2025.3.19: Fast Gemma3 patching. Transformers: 4.50.0.dev0. vLLM: 0.8.2.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/4.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/192 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Model loaded successfully!
# Loading development examples...
# Loaded 542 dev examples
#
# ================================================================================
# RUNNING FULL EVALUATION ON DEV SET
# ================================================================================
# Verbose output enabled - showing all examples
# Starting evaluation on 100 examples...
#
# --------------------------------------------------------------------------------
# Example 1/100 [INCORRECT]
# Question: by how much did the weighted average exercise price per share increase from 2005 to 2007?
#
# Expected answer: 142.4%
# Model answer: 141%
#
# Full expected output:
# Step 1: subtract(60.94, 25.14) = 35.80
# Step 2: divide(#0, 25.14) = 142.4%
# </think>
# Final Answer: 142.4%
#
# Full model output:
# Step 1: subtract(60.94, 25.14) = 35.8
# Step 2: divide(#0, 25.14) = 141%
# </think>
# Final Answer: 141%
# Generation time: 37.91 seconds
#
# --------------------------------------------------------------------------------
# Example 2/100 [EXACT MATCH]
# Question: what is the percentage change in the unamortized debt issuance costs associated with the senior notes from 2016 to 2017?
#
# Expected answer: -21.1%
# Model answer: -21.1%
# Generation time: 8.82 seconds
#
# --------------------------------------------------------------------------------
# Example 3/100 [EXACT MATCH]
# Question: what is the percentage change in the unamortized debt issuance costs associated with its credit facilities from 2016 to 2017?
#
# Expected answer: 37.5%
# Model answer: 37.5%
# Generation time: 8.53 seconds
#
# --------------------------------------------------------------------------------
# Example 4/100 [NUMERIC MATCH: 10.83% ≈ 11%]
# Question: what percentage of amounts expensed in 2009 came from discretionary company contributions?
#
# Expected answer: 10.83%
# Model answer: 11%
#
# Full expected output:
# Step 1: divide(3.8, 35.1) = 0.1083
# Step 2: multiply(#0, const_100) = 10.83
# </think>
# Final Answer: 10.83%
#
# Full model output:
# Step 1: divide(3.8, 35.1) = 11%
# </think>
# Final Answer: 11%
# Generation time: 5.93 seconds
#
# --------------------------------------------------------------------------------
# Example 5/100 [INCORRECT]
# Question: what was the percentage change in equipment rents payable from 2007 to 2008?
#
# Expected answer: -10%
# Model answer: -9.7%
#
# Full expected output:
# Step 1: subtract(93, 103) = -10
# Step 2: divide(#0, 103) = 10%
# </think>
# Final Answer: -10%
#
# Full model output:
# Step 1: subtract(93, 103) = -10
# Step 2: divide(#0, 103) = -9.7%
# </think>
# Final Answer: -9.7%
# Generation time: 8.83 seconds
#
# --------------------------------------------------------------------------------
# Example 6/100 [EXACT MATCH]
# Question: what was the ratio of the gallons hedged in 2017 to 2018
#
# Expected answer: 4
# Model answer: 4
# Generation time: 6.47 seconds
#
# --------------------------------------------------------------------------------
# Example 7/100 [NUMERIC MATCH: 14 ≈ 13.9]
# Question: what was the ratio of the aggregate fair values of our outstanding fuel hedges for 2015 and 2016
#
# Expected answer: 14
# Model answer: 13.9
#
# Full expected output:
# Step 1: divide(37.8, 2.7) = 14
# </think>
# Final Answer: 14
#
# Full model output:
# Step 1: divide(37.8, 2.7) = 13.9
# </think>
# Final Answer: 13.9
# Generation time: 6.14 seconds
#
# --------------------------------------------------------------------------------
# Example 8/100 [EXACT MATCH]
# Question: for 2016 , what was the total african and us net undeveloped acres expiring , in thousands ? \\n
#
# Expected answer: 257
# Model answer: 257
# Generation time: 5.45 seconds
#
# --------------------------------------------------------------------------------
# Example 9/100 [INCORRECT]
# Question: in 2018 , what percentage of undeveloped acres were located in the u.s?
#
# Expected answer: 12.6%
# Model answer: 6.7%
#
# Full expected output:
# Step 1: divide(128, 1018) = 12.6%
# </think>
# Final Answer: 12.6%
#
# Full model output:
# Step 1: divide(68, 1018) = 6.7%
# </think>
# Final Answer: 6.7%
# Generation time: 6.04 seconds
#
# --------------------------------------------------------------------------------
# Example 10/100 [INCORRECT]
# Question: what was the percentage change in cash provided by operating activities from 2012 to 2013?
#
# Expected answer: 11%
# Model answer: 10.7%
#
# Full expected output:
# Step 1: subtract(6823, 6161) = 662
# Step 2: divide(#0, 6161) = 11%
# </think>
# Final Answer: 11%
#
# Full model output:
# Step 1: subtract(6823, 6161) = 662
# Step 2: divide(#0, 6161) = 10.7%
# </think>
# Final Answer: 10.7%
# Generation time: 10.00 seconds
#
# --------------------------------------------------------------------------------
# Example 11/100 [INCORRECT]
# Question: what percentage of the total oil and gas mmboe comes from canada?
#
# Expected answer: 24.69%
# Model answer: 25%
#
# Full expected output:
# Step 1: divide(60, 243) = 0.2469
# Step 2: multiply(#0, const_100) = 24.69
# </think>
# Final Answer: 24.69%
#
# Full model output:
# Step 1: divide(60, 243) = 25%
# </think>
# Final Answer: 25%
# Generation time: 5.44 seconds
#
# --------------------------------------------------------------------------------
# Example 12/100 [EXACT MATCH]
# Question: what was the percent of the change in the risk and insurance brokerage services segment revenue from 2008 2009\\n
#
# Expected answer: 1.7%
# Model answer: 1.7%
# Generation time: 9.70 seconds
#
# --------------------------------------------------------------------------------
# Example 13/100 [INCORRECT]
# Question: what is the total return is $ 100000 are invested in s&p500 on january 1st , 2015 and sold at the end of 2016?
#
# Expected answer: 1877
# Model answer: 17100
#
# Full expected output:
# Step 1: subtract(129.05, 110.28) = 18.77
# Step 2: divide(100000, const_100) = 1000
# Step 3: multiply(#1, #0) = 1877
# </think>
# Final Answer: 1877
#
# Full model output:
# Step 1: subtract(129.05, 110.28) = 18.77
# Step 2: divide(#0, 110.28) = 17.1%
# Step 3: multiply(#1, 100000) = 17100
# </think>
# Final Answer: 17100
# Generation time: 15.33 seconds
#
# --------------------------------------------------------------------------------
# Example 14/100 [NUMERIC MATCH: 7.51% ≈ 7.5%]
# Question: what percent higher is fair value than carrying value?
#
# Expected answer: 7.51%
# Model answer: 7.5%
#
# Full expected output:
# Step 1: divide(5309, 4938) = 1.0751
# Step 2: subtract(#0, const_1) = .0751
# </think>
# Final Answer: 7.51%
#
# Full model output:
# Step 1: subtract(5309, 4938) = 371
# Step 2: divide(#0, 4938) = 7.5%
# </think>
# Final Answer: 7.5%
# Generation time: 9.70 seconds
#
# --------------------------------------------------------------------------------
# Example 15/100 [NUMERIC MATCH: 8% ≈ 8.2%]
# Question: what is the percent change in gas customers between 2007 and 2008?
#
# Expected answer: 8%
# Model answer: 8.2%
#
# Full expected output:
# Step 1: subtract(93000, 86000) = 7000
# Step 2: divide(#0, 86000) = 8%
# </think>
# Final Answer: 8%
#
# Full model output:
# Step 1: subtract(93000, 86000) = 7000
# Step 2: divide(#0, 86000) = 8.2%
# </think>
# Final Answer: 8.2%
# Generation time: 10.29 seconds
#
# --------------------------------------------------------------------------------
# Example 16/100 [EXACT MATCH]
# Question: what was the change in millions of operating income from 2016 to 2017?
#
# Expected answer: 688
# Model answer: 688
# Generation time: 6.27 seconds
#
# --------------------------------------------------------------------------------
# Example 17/100 [EXACT MATCH]
# Question: what are the net earnings attributable to pmi in the previous year , ( in billions ) ?
#
# Expected answer: 7.0
# Model answer: 7.0
# Generation time: 5.62 seconds
#
# --------------------------------------------------------------------------------
# Example 18/100 [EXACT MATCH]
# Question: what is the growth rate in total shipment volume from 2010 to 2011?
#
# Expected answer: 1.4%
# Model answer: 1.4%
# Generation time: 10.40 seconds
#
# --------------------------------------------------------------------------------
# Example 19/100 [NUMERIC MATCH: 37.7% ≈ 37.6%]
# Question: what is the percentage increase in total accumulated other comprehensive losses from 2014 to 2015?
#
# Expected answer: 37.7%
# Model answer: 37.6%
#
# Full expected output:
# Step 1: subtract(9402, 6826) = 2576
# Step 2: divide(#0, 6826) = 37.7%
# </think>
# Final Answer: 37.7%
#
# Full model output:
# Step 1: subtract(9402, 6826) = 2576
# Step 2: divide(#0, 6826) = 37.6%
# </think>
# Final Answer: 37.6%
# Generation time: 10.17 seconds
#
# --------------------------------------------------------------------------------
# Example 20/100 [NUMERIC MATCH: 62.9% ≈ 63%]
# Question: what is the percentage increase in total accumulated other comprehensive losses from 2013 to 2014?
#
# Expected answer: 62.9%
# Model answer: 63%
#
# Full expected output:
# Step 1: subtract(6826, 4190) = 2636
# Step 2: divide(#0, 4190) = 62.9%
# </think>
# Final Answer: 62.9%
#
# Full model output:
# Step 1: subtract(6826, 4190) = 2636
# Step 2: divide(#0, 4190) = 63%
# </think>
# Final Answer: 63%
# Generation time: 9.50 seconds
#
# --------------------------------------------------------------------------------
# Example 21/100 [INCORRECT]
# Question: assuming 2010 accrued casualty costs were completely repaired in the following year , ,what would the repairs and maintenance expense increase to for 2011 in millions?
#
# Expected answer: 2525
# Model answer: 6.399
#
# Full expected output:
# Step 1: multiply(2.2, const_1000) = 2200
# Step 2: add(325, #0) = 2525
# </think>
# Final Answer: 2525
#
# Full model output:
# Step 1: add(2.2, 2.0) = 4.2
# Step 2: add(#0, 1.9) = 6.1
# Step 3: add(#1, 249) = 6.399
# </think>
# Final Answer: 6.399
# Generation time: 12.69 seconds
#
# --------------------------------------------------------------------------------
# Example 22/100 [INCORRECT]
# Question: what is the average variance of the value at risk of each 2008 section? ( $ )
#
# Expected answer: 3.85
# Model answer: 3.4
#
# Full expected output:
# Step 1: subtract(4.7, .3) = 4.4
# Step 2: subtract(const_4, .7) = 3.3
# Step 3: add(#0, #1) = 7.7
# Step 4: divide(#2, const_2) = 3.85
# </think>
# Final Answer: 3.85
#
# Full model output:
# Step 1: add(1.8, 4.7) = 6.5
# Step 2: add(#0, .3) = 6.8
# Step 3: divide(#1, const_2) = 3.4
# </think>
# Final Answer: 3.4
# Generation time: 11.43 seconds
#
# --------------------------------------------------------------------------------
# Example 23/100 [INCORRECT]
# Question: what percent higher is the average var for foreign exchange products than that of interest rate products?
#
# Expected answer: 44%
# Model answer: 63.6%
#
# Full expected output:
# Step 1: add(1.1, 1.4) = 2.5
# Step 2: divide(#0, const_2) = 1.25
# </think>
# Final Answer: 44%
#
# Full model output:
# Step 1: divide(1.8, 1.1) = 1.636
# Step 2: subtract(#0, const_1) = 63.6%
# </think>
# Final Answer: 63.6%
# Generation time: 9.67 seconds
#
# --------------------------------------------------------------------------------
# Example 24/100 [INCORRECT]
# Question: what portion of total long-term borrowings is due in the next 36 months?
#
# Expected answer: 29.3%
# Model answer: 49.5%
#
# Full expected output:
# Step 1: add(750, 700) = 1450
# Step 2: divide(#0, 4950) = 29.3%
# </think>
# Final Answer: 29.3%
#
# Full model output:
# Step 1: add(750, 700) = 1450
# Step 2: add(#0, 1000) = 2450
# Step 3: divide(#1, 4950) = 49.5%
# </think>
# Final Answer: 49.5%
# Generation time: 13.51 seconds
#
# --------------------------------------------------------------------------------
# Example 25/100 [INCORRECT]
# Question: what amount of long-term debt due in the next 36 months as of december 31 , 2003 , in millions?
#
# Expected answer: 1041.5
# Model answer: 1041531
#
# Full expected output:
# Step 1: add(503215, 462420) = 965635
# Step 2: add(#0, 75896) = 1041531
# Step 3: divide(#1, const_1000) = 1041.5
# </think>
# Final Answer: 1041.5
#
# Full model output:
# Step 1: add(503215, 462420) = 965635
# Step 2: add(#0, 75896) = 1041531
# </think>
# Final Answer: 1041531
# Generation time: 12.10 seconds
#
# --------------------------------------------------------------------------------
# Example 26/100 [INCORRECT]
# Question: what was the percentage change of the net favorable prior period development from 2010 to 2008
#
# Expected answer: 38.2%
# Model answer: 61.7%
#
# Full expected output:
# Step 1: subtract(503, 814) = -311
# Step 2: divide(#0, 814) = 38.2%
# </think>
# Final Answer: 38.2%
#
# Full model output:
# Step 1: subtract(814, 503) = 311
# Step 2: divide(#0, 503) = 61.7%
# </think>
# Final Answer: 61.7%
# Generation time: 9.50 seconds
#
# --------------------------------------------------------------------------------
# Example 27/100 [EXACT MATCH]
# Question: what is the growth rate in net revenue in 2003 for entergy louisiana , inc.?
#
# Expected answer: 5.5%
# Model answer: 5.5%
# Generation time: 10.34 seconds
#
# --------------------------------------------------------------------------------
# Example 28/100 [INCORRECT]
# Question: payments to participants in the unfunded german plans are expected to be total approximately how much , in millions , for the years 2008 through 2012?
#
# Expected answer: 104
# Model answer: 156
#
# Full expected output:
# Step 1: subtract(2012, 2008) = 4
# Step 2: multiply(#0, 26) = 104
# </think>
# Final Answer: 104
#
# Full model output:
# Step 1: add(26, 26) = 52
# Step 2: add(#0, 26) = 78
# Step 3: add(#1, 26) = 104
# Step 4: add(#2, 26) = 130
# Step 5: add(#3, 26) = 156
# </think>
# Final Answer: 156
# Generation time: 17.05 seconds
#
# --------------------------------------------------------------------------------
# Example 29/100 [NUMERIC MATCH: 7.51% ≈ 7.5%]
# Question: what percent higher is fair value than carrying value?
#
# Expected answer: 7.51%
# Model answer: 7.5%
#
# Full expected output:
# Step 1: divide(5309, 4938) = 1.0751
# Step 2: subtract(#0, const_1) = .0751
# </think>
# Final Answer: 7.51%
#
# Full model output:
# Step 1: subtract(5309, 4938) = 371
# Step 2: divide(#0, 4938) = 7.5%
# </think>
# Final Answer: 7.5%
# Generation time: 9.69 seconds
#
# --------------------------------------------------------------------------------
# Example 30/100 [INCORRECT]
# Question: what is the fair value of all notes due by 2019 ? in millions $ .
#
# Expected answer: 2672
# Model answer: 1134000
#
# Full expected output:
# Step 1: add(753, 785) = 1538
# Step 2: add(1134, #0) = 2672
# </think>
# Final Answer: 2672
#
# Full model output:
# Step 1: multiply(1000, 1134) = 1134000
# </think>
# Final Answer: 1134000
# Generation time: 7.36 seconds
#
# --------------------------------------------------------------------------------
# Example 31/100 [INCORRECT]
# Question: what are the lease obligations to entergy louisiana as a percentage of long-term debt maturities in 2014?
#
# Expected answer: 38.7%
# Model answer: 3.9%
#
# Full expected output:
# Step 1: divide(385373, const_1000) = 385.373
# Step 2: divide(149, #0) = 38.7%
# </think>
# Final Answer: 38.7%
#
# Full model output:
# Step 1: divide(149, 385373) = 3.9%
# </think>
# Final Answer: 3.9%
# Generation time: 6.43 seconds
#
# --------------------------------------------------------------------------------
# Example 32/100 [INCORRECT]
# Question: at december 31 , 2008 what was the ratio of the tier 2 capital compared to 2007
#
# Expected answer: 0.94
# Model answer: 1
#
# Full expected output:
# Step 1: subtract(108.4, 71.0) = 37.4
# Step 2: subtract(121.6, 82.0) = 39.6
# Step 3: divide(#0, #1) = 0.94
# </think>
# Final Answer: 0.94
#
# Full model output:
# Step 1: divide(28.2, 28.2) = 1
# </think>
# Final Answer: 1
# Generation time: 5.24 seconds
#
# --------------------------------------------------------------------------------
# Example 33/100 [EXACT MATCH]
# Question: what was the change in billions in total capital ( tier 1 and tier 2 ) from 2007 to 2008?
#
# Expected answer: -13.2
# Model answer: -13.2
# Generation time: 6.65 seconds
#
# --------------------------------------------------------------------------------
# Example 34/100 [EXACT MATCH]
# Question: what is percentage change in rd&e spendings from 2013 to 2014?
#
# Expected answer: 8.3%
# Model answer: 8.3%
# Generation time: 9.39 seconds
#
# --------------------------------------------------------------------------------
# Example 35/100 [EXACT MATCH]
# Question: what is the applied 2019s net sales in 2018 , ( in billions ) ?
#
# Expected answer: 7.22
# Model answer: 7.22
# Generation time: 5.80 seconds
#
# --------------------------------------------------------------------------------
# Example 36/100 [EXACT MATCH]
# Question: what is the growth rate in net revenue in 2016?
#
# Expected answer: -7.4%
# Model answer: -7.4%
# Generation time: 9.76 seconds
#
# --------------------------------------------------------------------------------
# Example 37/100 [EXACT MATCH]
# Question: what was the average revenue from discontinued operations in 2013 and 2011 , in millions?
#
# Expected answer: 738.5
# Model answer: 738.5
# Generation time: 9.55 seconds
#
# --------------------------------------------------------------------------------
# Example 38/100 [NUMERIC MATCH: 4.27 ≈ 4.26]
# Question: what is the average liability for all three programs , as of december 31 , 2008 , in millions?
#
# Expected answer: 4.27
# Model answer: 4.26
#
# Full expected output:
# Step 1: add(1.2, 5.7) = 6.9
# Step 2: add(#0, 5.9) = 12.8
# Step 3: divide(#1, const_3) = 4.27
# </think>
# Final Answer: 4.27
#
# Full model output:
# Step 1: add(1.2, 5.7) = 6.9
# Step 2: add(#0, 5.9) = 12.8
# Step 3: divide(#1, const_3) = 4.26
# </think>
# Final Answer: 4.26
# Generation time: 12.49 seconds
#
# --------------------------------------------------------------------------------
# Example 39/100 [EXACT MATCH]
# Question: what was the percent of the decrease in the other intangible assets net from 2003 to 2004\\n
#
# Expected answer: -3.4%
# Model answer: -3.4%
# Generation time: 11.40 seconds
#
# --------------------------------------------------------------------------------
# Example 40/100 [EXACT MATCH]
# Question: what was the percentage cumulative total return for the five year period ended 31-dec-2017 of citi common stock?
#
# Expected answer: 93.5%
# Model answer: 93.5%
# Generation time: 10.36 seconds
#
# --------------------------------------------------------------------------------
# Example 41/100 [EXACT MATCH]
# Question: what is the percentage change in total gross amount of unrecognized tax benefits from 2017 to 2018?
#
# Expected answer: 13.4%
# Model answer: 13.4%
# Generation time: 11.40 seconds
#
# --------------------------------------------------------------------------------
# Example 42/100 [INCORRECT]
# Question: what is the total percentage decrease in future contingent acquisition obligations payable in cash from 2009-2013?
#
# Expected answer: 1.56%
# Model answer: 46.1%
#
# Full expected output:
# Step 1: subtract(76.7, 75.6) = 1.2
# Step 2: divide(#0, 76.7) = 0.0156
# Step 3: multiply(#1, const_100) = 1.56%
# </think>
# Final Answer: 1.56%
#
# Full model output:
# Step 1: subtract(139.9, 75.6) = 64.3
# Step 2: divide(#0, 139.9) = 46.1%
# </think>
# Final Answer: 46.1%
# Generation time: 10.49 seconds
#
# --------------------------------------------------------------------------------
# Example 43/100 [EXACT MATCH]
# Question: as of december 312012 what was the outstanding amount of share repurchase authorized in billions?
#
# Expected answer: 0.88
# Model answer: 0.88
# Generation time: 9.52 seconds
#
# --------------------------------------------------------------------------------
# Example 44/100 [INCORRECT]
# Question: by how much did the average price per share increase from 2010 to 2011?
#
# Expected answer: 25.9%
# Model answer: 25.6%
#
# Full expected output:
# Step 1: subtract(81.15, 64.48) = 16.67
# Step 2: divide(#0, 64.48) = 25.9%
# </think>
# Final Answer: 25.9%
#
# Full model output:
# Step 1: subtract(81.15, 64.48) = 16.67
# Step 2: divide(#0, 64.48) = 25.6%
# </think>
# Final Answer: 25.6%
# Generation time: 10.87 seconds
#
# --------------------------------------------------------------------------------
# Example 45/100 [EXACT MATCH]
# Question: what was the percentage cumulative 5-year total stockholder return for cadence design systems inc . for the five years ended 12/29/2012?
#
# Expected answer: -21.08%
# Model answer: -21.08%
# Generation time: 10.90 seconds
#
# --------------------------------------------------------------------------------
# Example 46/100 [INCORRECT]
# Question: what is the percentage change in total debt from 2014 to 2015?
#
# Expected answer: 3.4%
# Model answer: -3.4%
#
# Full expected output:
# Step 1: subtract(28.5, 29.5) = 1
# Step 2: divide(#0, 29.5) = 3.4%
# </think>
# Final Answer: 3.4%
#
# Full model output:
# Step 1: subtract(28.5, 29.5) = -1
# Step 2: divide(#0, 29.5) = -3.4%
# </think>
# Final Answer: -3.4%
# Generation time: 9.42 seconds
#
# --------------------------------------------------------------------------------
# Example 47/100 [EXACT MATCH]
# Question: at december 31 , 2013 what was the percent of square feet of our office in alpharetta , georgia not leased
#
# Expected answer: 65%
# Model answer: 65%
# Generation time: 6.64 seconds
#
# --------------------------------------------------------------------------------
# Example 48/100 [NUMERIC MATCH: 2.37 ≈ 2.38]
# Question: at december 31 , 2013 what was the ratio of square feet of our office in alpharetta , georgia to the jersey city new jersey
#
# Expected answer: 2.37
# Model answer: 2.38
#
# Full expected output:
# Step 1: divide(254000, 107000) = 2.37
# </think>
# Final Answer: 2.37
#
# Full model output:
# Step 1: divide(254000, 107000) = 2.38
# </think>
# Final Answer: 2.38
# Generation time: 7.00 seconds
#
# --------------------------------------------------------------------------------
# Example 49/100 [EXACT MATCH]
# Question: what was the percent of the change in the net revenues from dec . 282012 dec . 29 2013
#
# Expected answer: -1.2%
# Model answer: -1.2%
# Generation time: 10.13 seconds
#
# --------------------------------------------------------------------------------
# Example 50/100 [INCORRECT]
# Question: what was the percent of the impairment charges to the net revenue in 2013
#
# Expected answer: 0.5%
# Model answer: 1.7%
#
# Full expected output:
# Step 1: divide(240, 52708) = 0.5%
# </think>
# Final Answer: 0.5%
#
# Full model output:
# Step 1: divide(240, 13834) = 1.7%
# </think>
# Final Answer: 1.7%
# Generation time: 6.25 seconds
#
# --------------------------------------------------------------------------------
# Example 51/100 [INCORRECT]
# Question: what was the percentage change in operating income from 2016 to 2017?
#
# Expected answer: 6%
# Model answer: 6.3%
#
# Full expected output:
# Step 1: subtract(11503, 10815) = 688
# Step 2: divide(#0, 10815) = 6%
# </think>
# Final Answer: 6%
#
# Full model output:
# Step 1: subtract(11503, 10815) = 688
# Step 2: divide(#0, 10815) = 6.3%
# </think>
# Final Answer: 6.3%
# Generation time: 10.15 seconds
#
# --------------------------------------------------------------------------------
# Example 52/100 [INCORRECT]
# Question: what is the net change in cash in 2010?
#
# Expected answer: -135
# Model answer: -1135
#
# Full expected output:
# Step 1: add(3547, -319) = 3228
# Step 2: add(#0, -3363) = -135
# </think>
# Final Answer: -135
#
# Full model output:
# Step 1: add(3547, -319) = 3228
# Step 2: add(#0, -3363) = -1135
# </think>
# Final Answer: -1135
# Generation time: 9.60 seconds
#
# --------------------------------------------------------------------------------
# Example 53/100 [INCORRECT]
# Question: what is the percent change in minimum annual rental payment between 2010 and 2011?
#
# Expected answer: 1.3%
# Model answer: 1%
#
# Full expected output:
# Step 1: subtract(3200, 3160) = 40
# Step 2: divide(#0, 3160) = 1.3%
# </think>
# Final Answer: 1.3%
#
# Full model output:
# Step 1: subtract(3200, 3160) = 40
# Step 2: divide(#0, 3160) = 1%
# </think>
# Final Answer: 1%
# Generation time: 8.84 seconds
#
# --------------------------------------------------------------------------------
# Example 54/100 [INCORRECT]
# Question: what is the average amortization amount , in millions , from 2015-2019?
#
# Expected answer: 44.8
# Model answer: 67.25
#
# Full expected output:
# Step 1: multiply(45, const_4) = 180
# Step 2: add(#0, 44) = 224
# Step 3: divide(#1, const_5) = 44.8
# </think>
# Final Answer: 44.8
#
# Full model output:
# Step 1: add(45, 45) = 90
# Step 2: add(#0, 45) = 135
# Step 3: add(#1, 45) = 180
# Step 4: add(#2, 45) = 225
# Step 5: add(#3, 44) = 269
# Step 6: divide(#4, const_4) = 67.25
# </think>
# Final Answer: 67.25
# Generation time: 20.94 seconds
#
# --------------------------------------------------------------------------------
# Example 55/100 [EXACT MATCH]
# Question: what was the total return percentage for e*trade financial corporation for the five years ended 12/14?
#
# Expected answer: 37.81%
# Model answer: 37.81%
# Generation time: 11.14 seconds
#
# --------------------------------------------------------------------------------
# Example 56/100 [NUMERIC MATCH: 3.6% ≈ 3.5%]
# Question: what is the percentage change in average of investments from 2014 to 2015?
#
# Expected answer: 3.6%
# Model answer: 3.5%
#
# Full expected output:
# Step 1: subtract(17430.8, 16831.9) = 598.9
# Step 2: divide(#0, 16831.9) = 3.6%
# </think>
# Final Answer: 3.6%
#
# Full model output:
# Step 1: subtract(17430.8, 16831.9) = 598.9
# Step 2: divide(#0, 16831.9) = 3.5%
# </think>
# Final Answer: 3.5%
# Generation time: 11.61 seconds
#
# --------------------------------------------------------------------------------
# Example 57/100 [INCORRECT]
# Question: what is the growth rate in the price of shares from the highest value during the quarter ended december 31 , 2010 and the closing price on february 11 , 2011?
#
# Expected answer: 6.8%
# Model answer: -6.3%
#
# Full expected output:
# Step 1: subtract(56.73, 53.14) = 3.59
# Step 2: divide(#0, 53.14) = 6.8%
# </think>
# Final Answer: 6.8%
#
# Full model output:
# Step 1: subtract(53.14, 56.73) = -3.59
# Step 2: divide(#0, 56.73) = -6.3%
# </think>
# Final Answer: -6.3%
# Generation time: 10.38 seconds
#
# --------------------------------------------------------------------------------
# Example 58/100 [INCORRECT]
# Question: what is the total amount of cash outflow used for shares repurchased during november 2007 , in millions?
#
# Expected answer: 20.7
# Model answer: 3.7
#
# Full expected output:
# Step 1: multiply(431170, 48.11) = 20743588.7
# Step 2: divide(#0, const_1000000) = 20.7
# </think>
# Final Answer: 20.7
#
# Full model output:
# Step 1: multiply(8310, 44.99) = 371262.9
# Step 2: divide(#0, const_1000000) = 3.7
# </think>
# Final Answer: 3.7
# Generation time: 11.09 seconds
#
# --------------------------------------------------------------------------------
# Example 59/100 [INCORRECT]
# Question: for the fourth quarter ended december 312018 what was the total number of shares purchased in november
#
# Expected answer: 47.6%
# Model answer: 1216.469
#
# Full expected output:
# Step 1: divide(3655945, 7673266) = 47.6%
# </think>
# Final Answer: 47.6%
#
# Full model output:
# Step 1: divide(3655945, const_1000) = 3655.945
# Step 2: divide(3439476, const_1000) = 3439.476
# Step 3: subtract(#0, #1) = 1216.469
# </think>
# Final Answer: 1216.469
# Generation time: 17.52 seconds
#
# --------------------------------------------------------------------------------
# Example 60/100 [EXACT MATCH]
# Question: as of december 2018 what was the percent of the 2018 program still outstanding
#
# Expected answer: 88%
# Model answer: 88%
# Generation time: 5.67 seconds
#
# --------------------------------------------------------------------------------
# Example 61/100 [EXACT MATCH]
# Question: what is the percentage change in the balance of the prudential insurance company of america from 2016 to 2017?
#
# Expected answer: -1.3%
# Model answer: -1.3%
# Generation time: 10.95 seconds
#
# --------------------------------------------------------------------------------
# Example 62/100 [EXACT MATCH]
# Question: what was the ratio of the 2016 hedged gallons to 2017
#
# Expected answer: 2.25
# Model answer: 2.25
# Generation time: 7.63 seconds
#
# --------------------------------------------------------------------------------
# Example 63/100 [NUMERIC MATCH: 9.9% ≈ 10%]
# Question: what is the percentage growth of the aggregate fair values of our outstanding fuel hedge for 2014 to 2015
#
# Expected answer: 9.9%
# Model answer: 10%
#
# Full expected output:
# Step 1: subtract(37.8, 34.4) = 3.4
# Step 2: divide(#0, 34.4) = 9.9%
# </think>
# Final Answer: 9.9%
#
# Full model output:
# Step 1: subtract(37.8, 34.4) = 3.4
# Step 2: divide(#0, 34.4) = 10%
# </think>
# Final Answer: 10%
# Generation time: 9.37 seconds
#
# --------------------------------------------------------------------------------
# Example 64/100 [INCORRECT]
# Question: what was the percentage change in raw materials and supplies between 2017 and 2018?
#
# Expected answer: 4%
# Model answer: 3.6%
#
# Full expected output:
# Step 1: subtract(506.5, 488.8) = 17.7
# Step 2: divide(#0, 488.8) = 4%
# </think>
# Final Answer: 4%
#
# Full model output:
# Step 1: subtract(506.5, 488.8) = 17.7
# Step 2: divide(#0, 488.8) = 3.6%
# </think>
# Final Answer: 3.6%
# Generation time: 10.38 seconds
#
# --------------------------------------------------------------------------------
# Example 65/100 [EXACT MATCH]
# Question: what was the percentage change in investment banking fees from 2006 to 2007?
#
# Expected answer: 20%
# Model answer: 20%
# Generation time: 9.53 seconds
#
# --------------------------------------------------------------------------------
# Example 66/100 [EXACT MATCH]
# Question: what is the percentage change in net comodities from 2016 to 2017?
#
# Expected answer: -35.6%
# Model answer: -35.6%
# Generation time: 8.99 seconds
#
# --------------------------------------------------------------------------------
# Example 67/100 [EXACT MATCH]
# Question: what is the percentage reduction in the loews common stock from 2013 to 2014
#
# Expected answer: -12.4%
# Model answer: -12.4%
# Generation time: 11.40 seconds
#
# --------------------------------------------------------------------------------
# Example 68/100 [EXACT MATCH]
# Question: what is the difference in payments between entergy arkansas and entergy louisiana , in millions?
#
# Expected answer: 4
# Model answer: 4
# Generation time: 4.29 seconds
#
# --------------------------------------------------------------------------------
# Example 69/100 [EXACT MATCH]
# Question: what are the payments for entergy arkansas as a percentage of payments for entergy louisiana?
#
# Expected answer: 33.3%
# Model answer: 33.3%
# Generation time: 5.64 seconds
#
# --------------------------------------------------------------------------------
# Example 70/100 [INCORRECT]
# Question: considering the year 2013 , what is the sales to operating income ratio?
#
# Expected answer: 6.88
# Model answer: 6.8
#
# Full expected output:
# Step 1: divide(451.1, 65.5) = 6.88
# </think>
# Final Answer: 6.88
#
# Full model output:
# Step 1: divide(451.1, 65.5) = 6.8
# </think>
# Final Answer: 6.8
# Generation time: 6.15 seconds
#
# --------------------------------------------------------------------------------
# Example 71/100 [NUMERIC MATCH: 9.41 ≈ 9.4]
# Question: considering the year 2012 , what is the sales to operating income ratio?
#
# Expected answer: 9.41
# Model answer: 9.4
#
# Full expected output:
# Step 1: divide(420.1, 44.6) = 9.41
# </think>
# Final Answer: 9.41
#
# Full model output:
# Step 1: divide(420.1, 44.6) = 9.4
# </think>
# Final Answer: 9.4
# Generation time: 6.09 seconds
#
# --------------------------------------------------------------------------------
# Example 72/100 [INCORRECT]
# Question: what is the percent change in net revenue from 2015 to 2016?
#
# Expected answer: 8.04%
# Model answer: -7.4%
#
# Full expected output:
# Step 1: subtract(1666, 1542) = 124
# Step 2: divide(#0, 1542) = 8.04%
# </think>
# Final Answer: 8.04%
#
# Full model output:
# Step 1: subtract(1542, 1666) = -124
# Step 2: divide(#0, 1666) = -7.4%
# </think>
# Final Answer: -7.4%
# Generation time: 9.68 seconds
#
# --------------------------------------------------------------------------------
# Example 73/100 [NUMERIC MATCH: 4.41% ≈ 4.4%]
# Question: what are the nuclear fuel expenses as a percentage of 2016 net revenue?
#
# Expected answer: 4.41%
# Model answer: 4.4%
#
# Full expected output:
# Step 1: divide(68, 1542) = 4.41%
# </think>
# Final Answer: 4.41%
#
# Full model output:
# Step 1: divide(68, 1542) = 4.4%
# </think>
# Final Answer: 4.4%
# Generation time: 5.98 seconds
#
# --------------------------------------------------------------------------------
# Example 74/100 [INCORRECT]
# Question: considering the year 2012 , how bigger is the capital expenditures on a non-gaap basis than the one on a gaap basis?
#
# Expected answer: 8.53%
# Model answer: 218.5
#
# Full expected output:
# Step 1: divide(2778.3, 2559.8) = 1.0853
# Step 2: subtract(#0, const_1) = 8.53%
# </think>
# Final Answer: 8.53%
#
# Full model output:
# Step 1: subtract(2778.3, 2559.8) = 218.5
# </think>
# Final Answer: 218.5
# Generation time: 7.29 seconds
#
# --------------------------------------------------------------------------------
# Example 75/100 [EXACT MATCH]
# Question: what was the percentage return for pmi common stock for the five years ended 2018?
#
# Expected answer: -3.5%
# Model answer: -3.5%
# Generation time: 9.85 seconds
#
# --------------------------------------------------------------------------------
# Example 76/100 [NUMERIC MATCH: 965.6 ≈ 965.635]
# Question: what amount of long-term debt due in the next 24 months as of december 31 , 2003 , in millions?
#
# Expected answer: 965.6
# Model answer: 965.635
#
# Full expected output:
# Step 1: add(503215, 462420) = 965635
# Step 2: divide(#0, const_1000) = 965.6
# </think>
# Final Answer: 965.6
#
# Full model output:
# Step 1: add(503215, 462420) = 965635
# Step 2: divide(#0, const_1000) = 965.635
# </think>
# Final Answer: 965.635
# Generation time: 12.06 seconds
#
# --------------------------------------------------------------------------------
# Example 77/100 [INCORRECT]
# Question: what amount of long-term debt due in the next 36 months as of december 31 , 2003 , in millions?
#
# Expected answer: 1041.5
# Model answer: 1041531
#
# Full expected output:
# Step 1: add(503215, 462420) = 965635
# Step 2: add(#0, 75896) = 1041531
# Step 3: divide(#1, const_1000) = 1041.5
# </think>
# Final Answer: 1041.5
#
# Full model output:
# Step 1: add(503215, 462420) = 965635
# Step 2: add(#0, 75896) = 1041531
# </think>
# Final Answer: 1041531
# Generation time: 12.07 seconds
#
# --------------------------------------------------------------------------------
# Example 78/100 [INCORRECT]
# Question: what is the fair value of hologic common stock used to acquire suros?
#
# Expected answer: 46.3
# Model answer: 2449500
#
# Full expected output:
# Step 1: divide(106500, 2300) = 46.3
# </think>
# Final Answer: 46.3
#
# Full model output:
# Step 1: divide(2300, const_1000) = 2.3
# Step 2: multiply(#0, 106500) = 2449500
# </think>
# Final Answer: 2449500
# Generation time: 11.28 seconds
#
# --------------------------------------------------------------------------------
# Example 79/100 [INCORRECT]
# Question: what portion of the total acquisition price of suros is dedicated to goodwill?
#
# Expected answer: 75.6%
# Model answer: 76%
#
# Full expected output:
# Step 1: divide(202000, 267100) = 75.6%
# </think>
# Final Answer: 75.6%
#
# Full model output:
# Step 1: divide(202000, 267100) = 76%
# </think>
# Final Answer: 76%
# Generation time: 6.68 seconds
#
# --------------------------------------------------------------------------------
# Example 80/100 [EXACT MATCH]
# Question: what was the percentage growth in the operating profit as reported from 2017 to 2018
#
# Expected answer: 1.4%
# Model answer: 1.4%
# Generation time: 9.51 seconds
#
# --------------------------------------------------------------------------------
# Example 81/100 [NUMERIC MATCH: 3.8% ≈ 3.8]
# Question: what was the difference in operating profit for the americas as a percentage of net sales between 2001 and 2003?
#
# Expected answer: 3.8%
# Model answer: 3.8
#
# Full expected output:
# Step 1: subtract(51.2, 47.4) = 3.8
# </think>
# Final Answer: 3.8%
#
# Full model output:
# Step 1: subtract(51.2, 47.4) = 3.8
# </think>
# Final Answer: 3.8
# Generation time: 5.97 seconds
#
# --------------------------------------------------------------------------------
# Example 82/100 [NUMERIC MATCH: 6.8% ≈ 6.8]
# Question: what was the difference in operating profit for europe as a percentage of net sales between 2001 and 2003?
#
# Expected answer: 6.8%
# Model answer: 6.8
#
# Full expected output:
# Step 1: subtract(26.3, 19.5) = 6.8
# </think>
# Final Answer: 6.8%
#
# Full model output:
# Step 1: subtract(26.3, 19.5) = 6.8
# </think>
# Final Answer: 6.8
# Generation time: 5.94 seconds
#
# --------------------------------------------------------------------------------
# Example 83/100 [INCORRECT]
# Question: compared to the s&p 500 ,what was the difference in percentage growth from the s&p 500 retail index .
#
# Expected answer: 73.4%
# Model answer: 74.46%
#
# Full expected output:
# Step 1: subtract(211.67, 100) = 111.67
# Step 2: divide(#0, 100) = 112.7%
# Step 3: subtract(286.13, 100) = 186.13
# Step 4: divide(#2, 100) = 186.1%
# Step 5: subtract(#3, #1) = 73.4%
# </think>
# Final Answer: 73.4%
#
# Full model output:
# Step 1: subtract(286.13, const_100) = 186.13
# Step 2: divide(#0, const_100) = 186.13%
# Step 3: subtract(211.67, const_100) = 111.67
# Step 4: divide(#2, const_100) = 111.67%
# Step 5: subtract(#1, #3) = 74.46%
# </think>
# Final Answer: 74.46%
# Generation time: 23.58 seconds
#
# --------------------------------------------------------------------------------
# Example 84/100 [INCORRECT]
# Question: for the mtn group acquisition , what was the cost per tower ? .
#
# Expected answer: 1798334
# Model answer: 180.5
#
# Full expected output:
# Step 1: multiply(173.2, const_1000000) = 173200000
# Step 2: divide(#0, 962) = 1798334
# </think>
# Final Answer: 1798334
#
# Full model output:
# Step 1: multiply(173.2, const_1000000) = 173200000
# Step 2: divide(#0, 962) = 180.5
# </think>
# Final Answer: 180.5
# Generation time: 11.70 seconds
#
# --------------------------------------------------------------------------------
# Example 85/100 [INCORRECT]
# Question: how many total votes can the class b-3 provide in 2017?
#
# Expected answer: 1300
# Model answer: 3 Step 45: multiply(#4
#
# Full expected output:
# Step 1: multiply(const_1000, 1.3) = 1300
# Step 2: multiply(const_1, #0) = 1300
# </think>
# Final Answer: 1300
#
# Full model output:
# Step 1: multiply(1.3, const_1000) = 1300
# Step 2: divide(#0, const_1000) = 1.3
# Step 3: multiply(#1, const_1000) = 1300
# Step 4: divide(#2, const_1000) = 1.3
# Step 5: multiply(#3, const_1000) = 1300
# Step 6: divide(#4, const_1000) = 1.3
# Step 7: multiply(#5, const_1000) = 1300
# Step 8: divide(#6, const_1000) = 1.3
# Step 9: multiply(#7, const_1000) = 1300
# Step 10: divide(#8, const_1000) = 1.3
# Step 11: multiply(#9, const_1000) = 1300
# Step 12: divide(#10, const_1000) = 1.3
# Step 13: multiply(#11, const_1000...
# Generation time: 172.47 seconds
#
# --------------------------------------------------------------------------------
# Example 86/100 [INCORRECT]
# Question: what are the total contingent payments relating to impella?
#
# Expected answer: 5583331
# Model answer: 16749999
#
# Full expected output:
# Step 1: multiply(5583334, const_3) = 5583331
# </think>
# Final Answer: 5583331
#
# Full model output:
# Step 1: add(5583333, 5583333) = 11166666
# Step 2: add(#0, 5583334) = 16749999
# </think>
# Final Answer: 16749999
# Generation time: 13.31 seconds
#
# --------------------------------------------------------------------------------
# Example 87/100 [INCORRECT]
# Question: what was the average payment per year for the state tax settlement , in millions?
#
# Expected answer: 56
# Model answer: 42
#
# Full expected output:
# Step 1: divide(168, const_3) = 56
# </think>
# Final Answer: 56
#
# Full model output:
# Step 1: divide(168, const_4) = 42
# </think>
# Final Answer: 42
# Generation time: 5.09 seconds
#
# --------------------------------------------------------------------------------
# Example 88/100 [INCORRECT]
# Question: what portion of the long-term debt is reported under the current liabilities section of balance sheet as of september 27 , 2008?
#
# Expected answer: 1.7%
# Model answer: 17.5%
#
# Full expected output:
# Step 1: divide(38480, 2200900) = 1.7%
# </think>
# Final Answer: 1.7%
#
# Full model output:
# Step 1: divide(38480, 2200900) = 17.5%
# </think>
# Final Answer: 17.5%
# Generation time: 7.33 seconds
#
# --------------------------------------------------------------------------------
# Example 89/100 [EXACT MATCH]
# Question: what portion of the total contractual obligations are due within the next 12 months?
#
# Expected answer: 5.8%
# Model answer: 5.8%
# Generation time: 7.13 seconds
#
# --------------------------------------------------------------------------------
# Example 90/100 [INCORRECT]
# Question: for the mtn group acquisition , what was the cost per tower ? .
#
# Expected answer: 1798334
# Model answer: 1.8
#
# Full expected output:
# Step 1: multiply(173.2, const_1000000) = 173200000
# Step 2: divide(#0, 962) = 1798334
# </think>
# Final Answer: 1798334
#
# Full model output:
# Step 1: divide(173.2, 1000) = 173.2
# Step 2: divide(#0, 962) = 1.8
# </think>
# Final Answer: 1.8
# Generation time: 9.67 seconds
#
# --------------------------------------------------------------------------------
# Example 91/100 [EXACT MATCH]
# Question: for the mtn deal , what was the total post closing adjustments , in millions?
#
# Expected answer: 1.7
# Model answer: 1.7
# Generation time: 6.29 seconds
#
# --------------------------------------------------------------------------------
# Example 92/100 [EXACT MATCH]
# Question: what percentage of total other assets in 2012 was comprised of goodwill and identifiable intangible assets?
#
# Expected answer: 13%
# Model answer: 13%
# Generation time: 6.10 seconds
#
# --------------------------------------------------------------------------------
# Example 93/100 [INCORRECT]
# Question: what percentage of total other assets in 2011 was comprised of goodwill and identifiable intangible assets?
#
# Expected answer: 24%
# Model answer: 23.6%
#
# Full expected output:
# Step 1: divide(5468, 23152) = 24%
# </think>
# Final Answer: 24%
#
# Full model output:
# Step 1: divide(5468, 23152) = 23.6%
# </think>
# Final Answer: 23.6%
# Generation time: 6.81 seconds
#
# --------------------------------------------------------------------------------
# Example 94/100 [INCORRECT]
# Question: what is the average price of the increased electricity usage per gwh?
#
# Expected answer: 18068.8
# Model answer: 13075
#
# Full expected output:
# Step 1: multiply(18.9, const_1000000) = 18900000
# Step 2: divide(#0, 1046) = 18068.8
# </think>
# Final Answer: 18068.8
#
# Full model output:
# Step 1: divide(1046, 8%) = 13075
# </think>
# Final Answer: 13075
# Generation time: 6.14 seconds
#
# --------------------------------------------------------------------------------
# Example 95/100 [NUMERIC MATCH: 3.5% ≈ 3.4%]
# Question: what was the percentage change in net revenue in 2011
#
# Expected answer: 3.5%
# Model answer: 3.4%
#
# Full expected output:
# Step 1: add(18.9, -0.3) = 18.6
# Step 2: add(#0, 536.7) = 3.5%
# </think>
# Final Answer: 3.5%
#
# Full model output:
# Step 1: subtract(555.3, 536.7) = 18.6
# Step 2: divide(#0, 536.7) = 3.4%
# </think>
# Final Answer: 3.4%
# Generation time: 10.33 seconds
#
# --------------------------------------------------------------------------------
# Example 96/100 [EXACT MATCH]
# Question: at december 31 , what was the percentage change in investment income from 2011 to 2012
#
# Expected answer: -3.2%
# Model answer: -3.2%
# Generation time: 10.33 seconds
#
# --------------------------------------------------------------------------------
# Example 97/100 [INCORRECT]
# Question: at the end of 2014 , the notional value of derivatives designated as hedging instruments under gaap was what percent of the fair value?
#
# Expected answer: 3044%
# Model answer: 30.5
#
# Full expected output:
# Step 1: divide(36197, 1189) = 3044%
# </think>
# Final Answer: 3044%
#
# Full model output:
# Step 1: divide(36197, 1189) = 30.5
# </think>
# Final Answer: 30.5
# Generation time: 6.41 seconds
#
# --------------------------------------------------------------------------------
# Example 98/100 [EXACT MATCH]
# Question: was the notional amount of derivatives designated as hedging instruments under gaap greater than the notional amount of\\nderivatives not designated as hedging instruments under gaap?
#
# Expected answer: no
# Model answer: no
# Generation time: 6.26 seconds
#
# --------------------------------------------------------------------------------
# Example 99/100 [EXACT MATCH]
# Question: what was the percentage growth in sales of cabinets from 2016 to 2017
#
# Expected answer: 2.9%
# Model answer: 2.9%
# Generation time: 10.89 seconds
#
# --------------------------------------------------------------------------------
# Example 100/100 [EXACT MATCH]
# Question: what was the average net revenue between 2016 and 2017 in millions
#
# Expected answer: 1521.55
# Model answer: 1521.55
# Generation time: 11.51 seconds
#
# All predictions written to: /content/drive/MyDrive/2025_ConvFinQA_SFT_Agentic/evaluation_outputs/all_predictions_program_full.jsonl
#
# ================================================================================
# EVALUATION RESULTS
# ================================================================================
# Total examples evaluated: 100
# Average generation time: 11.25 seconds
# Exact match accuracy: 39.00%
# Numeric match accuracy (includes exact + approximate): 56.00%
# Exact matches: 39/100
# Numeric-only matches: 17/100
#
# ================================================================================
# ROUNDING DIFFERENCE ANALYSIS
# ================================================================================
# Found 15 examples with rounding differences
# These are counted as correct in the numeric match accuracy
#
# Examples of rounding differences:
#
# Rounding Example 1:
# Question: what percentage of amounts expensed in 2009 came from discretionary company contributions?
# Expected: 10.83%
# Model: 11%
# Difference: 0.17
#
# Rounding Example 2:
# Question: what was the ratio of the aggregate fair values of our outstanding fuel hedges for 2015 and 2016
# Expected: 14
# Model: 13.9
# Difference: 0.10
#
# Rounding Example 3:
# Question: what percent higher is fair value than carrying value?
# Expected: 7.51%
# Model: 7.5%
# Difference: 0.01
#
# Rounding Example 4:
# Question: what is the percent change in gas customers between 2007 and 2008?
# Expected: 8%
# Model: 8.2%
# Difference: 0.20
#
# Rounding Example 5:
# Question: what is the percentage increase in total accumulated other comprehensive losses from 2014 to 2015?
# Expected: 37.7%
# Model: 37.6%
# Difference: 0.10
#
# ================================================================================
# ERROR ANALYSIS
# ================================================================================
# Accuracy by reasoning step count:
#   1 steps: 13.79% (20/145)
#   2 steps: 15.00% (51/340)
#   3 steps: 4.44% (2/45)
#   4 steps: 0.00% (0/4)
#   5 steps: 0.00% (0/8)
#
# Detailed results saved to /content/drive/MyDrive/2025_ConvFinQA_SFT_Agentic/evaluation_outputs/evaluation_results_program_full.json
#
# Evaluation complete!
